# %% [markdown]
# <a href="https://colab.research.google.com/github/mtsilimos/Codesnippets_Sentence-Embeddings-for-the-Classification-of-Explicit-Fine-grained-Discourse-Relations/blob/main/Doc2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/finalcorpus.csv', ';', encoding= 'unicode_escape')

df['text'].head()
# Out:
# <ipython-input-221-4e3c29eaf277>:3: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df = pd.read_csv('/content/drive/My Drive/finalcorpus.csv', ';', encoding= 'unicode_escape')
# 0    Once she asked for daddy, but went back to sle...
# 1    The medication they were giving her to clear u...
# 2        You can sit up, but you have to stay in there
# 3    She met his gaze defiantly for a moment longer...
# 4    If it's something we simply can't afford, that...
# Name: text, dtype: object

# %%
df['label'].value_counts()
# Out:
# 0    1000
# 1    1000
# Name: label, dtype: int64

# %%
def clean_text(text):
    text = text.lower()

    text = " ".join(text.split())
    return text


df['clean']= df['text'].map(clean_text)

df
# Out:
#                                                    text  label  \
# 0     Once she asked for daddy, but went back to sle...      0
# 1     The medication they were giving her to clear u...      0
# 2         You can sit up, but you have to stay in there      0
# 3     She met his gaze defiantly for a moment longer...      0
# 4     If it's something we simply can't afford, that...      0
# ...                                                 ...    ...
# 1995  while\t  I was gone your mother saw some paper...      1
# 1996  you can stop and start  \twhile\t  you are mak...      1
# 1997  We've closed the road off  \twhile\t  the boys...      1
# 1998  Take the shipment  \twhile\t  it's still on th...      1
# 1999  He escaped and managed to get to England  \twh...      1
#
#                                                   clean
# 0     once she asked for daddy, but went back to sle...
# 1     the medication they were giving her to clear u...
# 2         you can sit up, but you have to stay in there
# 3     she met his gaze defiantly for a moment longer...
# 4     if it's something we simply can't afford, that...
# ...                                                 ...
# 1995  while i was gone your mother saw some papers i...
# 1996  you can stop and start while you are making a ...
# 1997  we've closed the road off while the boys go ov...
# 1998    take the shipment while it's still on the river
# 1999  he escaped and managed to get to england while...
#
# [2000 rows x 3 columns]

# %%
df['text_clean'] = df['clean'].str.replace(r'[^\w\s]+', '')
df
# Out:
# <ipython-input-224-54813a71aa81>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['text_clean'] = df['clean'].str.replace(r'[^\w\s]+', '')
#                                                    text  label  \
# 0     Once she asked for daddy, but went back to sle...      0
# 1     The medication they were giving her to clear u...      0
# 2         You can sit up, but you have to stay in there      0
# 3     She met his gaze defiantly for a moment longer...      0
# 4     If it's something we simply can't afford, that...      0
# ...                                                 ...    ...
# 1995  while\t  I was gone your mother saw some paper...      1
# 1996  you can stop and start  \twhile\t  you are mak...      1
# 1997  We've closed the road off  \twhile\t  the boys...      1
# 1998  Take the shipment  \twhile\t  it's still on th...      1
# 1999  He escaped and managed to get to England  \twh...      1
#
#                                                   clean  \
# 0     once she asked for daddy, but went back to sle...
# 1     the medication they were giving her to clear u...
# 2         you can sit up, but you have to stay in there
# 3     she met his gaze defiantly for a moment longer...
# 4     if it's something we simply can't afford, that...
# ...                                                 ...
# 1995  while i was gone your mother saw some papers i...
# 1996  you can stop and start while you are making a ...
# 1997  we've closed the road off while the boys go ov...
# 1998    take the shipment while it's still on the river
# 1999  he escaped and managed to get to england while...
#
#                                              text_clean
# 0     once she asked for daddy but went back to slee...
# 1     the medication they were giving her to clear u...
# 2          you can sit up but you have to stay in there
# 3     she met his gaze defiantly for a moment longer...
# 4     if its something we simply cant afford thats o...
# ...                                                 ...
# 1995  while i was gone your mother saw some papers i...
# 1996  you can stop and start while you are making a ...
# 1997  weve closed the road off while the boys go ove...
# 1998     take the shipment while its still on the river
# 1999  he escaped and managed to get to england while...
#
# [2000 rows x 4 columns]

# %%
pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.1 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.0.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.8/110.8 kB 12.4 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24

# %%
import contractions
df['cleaned'] = df['text_clean'].apply(lambda x: contractions.fix(x))
df
# Out:
#                                                    text  label  \
# 0     Once she asked for daddy, but went back to sle...      0
# 1     The medication they were giving her to clear u...      0
# 2         You can sit up, but you have to stay in there      0
# 3     She met his gaze defiantly for a moment longer...      0
# 4     If it's something we simply can't afford, that...      0
# ...                                                 ...    ...
# 1995  while\t  I was gone your mother saw some paper...      1
# 1996  you can stop and start  \twhile\t  you are mak...      1
# 1997  We've closed the road off  \twhile\t  the boys...      1
# 1998  Take the shipment  \twhile\t  it's still on th...      1
# 1999  He escaped and managed to get to England  \twh...      1
#
#                                                   clean  \
# 0     once she asked for daddy, but went back to sle...
# 1     the medication they were giving her to clear u...
# 2         you can sit up, but you have to stay in there
# 3     she met his gaze defiantly for a moment longer...
# 4     if it's something we simply can't afford, that...
# ...                                                 ...
# 1995  while i was gone your mother saw some papers i...
# 1996  you can stop and start while you are making a ...
# 1997  we've closed the road off while the boys go ov...
# 1998    take the shipment while it's still on the river
# 1999  he escaped and managed to get to england while...
#
#                                              text_clean  \
# 0     once she asked for daddy but went back to slee...
# 1     the medication they were giving her to clear u...
# 2          you can sit up but you have to stay in there
# 3     she met his gaze defiantly for a moment longer...
# 4     if its something we simply cant afford thats o...
# ...                                                 ...
# 1995  while i was gone your mother saw some papers i...
# 1996  you can stop and start while you are making a ...
# 1997  weve closed the road off while the boys go ove...
# 1998     take the shipment while its still on the river
# 1999  he escaped and managed to get to england while...
#
#                                                 cleaned
# 0     once she asked for daddy but went back to slee...
# 1     the medication they were giving her to clear u...
# 2          you can sit up but you have to stay in there
# 3     she met his gaze defiantly for a moment longer...
# 4     if its something we simply cannot afford that ...
# ...                                                 ...
# 1995  while i was gone your mother saw some papers i...
# 1996  you can stop and start while you are making a ...
# 1997  we have closed the road off while the boys go ...
# 1998     take the shipment while its still on the river
# 1999  he escaped and managed to get to england while...
#
# [2000 rows x 5 columns]

# %%
df.to_csv(r'C:\Users\mtsil\OneDrive\Documents\cleaneddoc.csv', ';')

# %%
df1 = pd.read_csv(r'C:\Users\mtsil\OneDrive\Documents\cleaneddoc.csv', ';', encoding= 'unicode_escape')
# Out:
# <ipython-input-227-43d737e86bb1>:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df1 = pd.read_csv(r'C:\Users\mtsil\OneDrive\Documents\cleaneddoc.csv', ';', encoding= 'unicode_escape')

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split

train, test = train_test_split (df1, test_size=.20, random_state=42)

tagged_tr = [TaggedDocument(words=word_tokenize(_d.lower()),
tags=[str(i)]) for i, _d in enumerate(train.text)]

tagged_test = [TaggedDocument(words=word_tokenize(_d.lower()),
tags=[str(i)]) for i, _d in enumerate(test.text)]

# %%
model = Doc2Vec(vector_size=300,
                window=5,
                alpha=.025,
                min_alpha=0.00025,
                min_count=2,
                dm=0,
                workers=8,
               negative = 10)
model.build_vocab(tagged_tr)

# %%
epochs = range(20)
for epoch in epochs:
    print(f'Epoch {epoch+1}')
    model.train(tagged_tr,
                total_examples=model.corpus_count,
                epochs=model.epochs)

    model.alpha -= 0.00025

    model.min_alpha = model.alpha
# Out:
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20

# %%
import numpy as np
X_train = np.array([model.dv[str(i)] for i in range(len(tagged_tr))])
y_train = train['label']

# %%
X_test = np.array([model.infer_vector(tagged_test[i][0]) for i in range(len(tagged_test))])
y_test = test['label']

# %%
from sklearn.naive_bayes import BernoulliNB

model = BernoulliNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm  = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[151,  48],
#        [ 46, 155]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.76       199
#            1       0.76      0.77      0.77       201
#
#     accuracy                           0.77       400
#    macro avg       0.77      0.76      0.76       400
# weighted avg       0.77      0.77      0.76       400
